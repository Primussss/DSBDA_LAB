# %% [markdown]
# <a href="https://colab.research.google.com/github/Primussss/DSBDA_LAB/blob/main/practical3_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as py
import matplotlib.pyplot as plt
import seaborn as sns
df = sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
import seaborn as sns
sns.displot(x=df['petal_width'], bins=10)
sns.displot(df['petal_length'], bins=10 , kde=False)

# %%
sns.jointplot (x=df['petal_length'], y=df['sepal_length'], kind='scatter')
sns.jointplot (x=df['petal_length'], y=df['sepal_length'], kind='hex')

# %%
sns.rugplot(df['sepal_length'])
# Out:
# <Axes: xlabel='sepal_length'>

# %%
#now we have categorical plots : 1.bar plot 2.count plot 3.box plot 4. voilin plot
import numpy as np

sns.barplot(x=df['species'], y=df['sepal_length'])
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.barplot(x=df['species'], y=df['sepal_length'], estimator=np.std)
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.countplot(x=df['species'], data=df)
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
sns.boxplot(x=df['species'], y=df['sepal_length'])
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.boxplot(x=df['species'], y=df['sepal_length'], hue=df['species'])
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.violinplot(x=df['species'], y=df['sepal_length'] , data=df)
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.violinplot(x=df['species'], y=df['sepal_length'] , data=df, hue=df['species'])
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
#now we will plot advance plots and matrix plot ad(a. Strip Plot ,b. Swarm Plot) ma(a. Heat Map ,b. Cluster Map)
import pandas as pd
import numpy as py
import matplotlib.pyplot as plt
import seaborn as sns
df = sns.load_dataset('iris')
sns.stripplot(x=df['species'], y=df['sepal_length'] , data=df , jitter=False)
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.stripplot(x=df['species'], y=df['sepal_length'] , data=df , jitter=True)
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.stripplot(x=df['species'], y=df['sepal_length'] , data=df , jitter=True, hue=df['species'])
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.swarmplot(x=df['species'], y=df['sepal_length'] , data=df)
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
import pandas as pd
import numpy as py
import matplotlib.pyplot as plt
import seaborn as sns
df = sns.load_dataset('iris')
sns.scatterplot(x=df['sepal_length'], y=df['sepal_width'] , data=df)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.scatterplot(x=df['sepal_length'], y=df['sepal_width'] , data=df, hue=df['species'], style=df['species'] )
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.pairplot(df, hue='species', height=2.5)

# %%
df['species'].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,7))
plt.style.use('Solarize_Light2')

# %%
df['species'].value_counts().plot.pie()
plt.show()

# %%
sns.barplot(x=df['species'], y=df['sepal_length'] , data=df, hue=df['species'])
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.violinplot(x=df['species'], y=df['sepal_length'] , data=df, hue=df['species'], palette='Set2')
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.barplot(x=df['species'], y=df['sepal_length'] , data=df, hue=df['species'], palette='Set2')
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.set_style('whitegrid')
sns.pairplot(df[['sepal_length','sepal_width','petal_length','petal_width']] , height=2.5)
plt.show()

# %%
sns.displot(x=df['petal_width'], bins=10)

# %%
df.columns.values
# Out:
# array(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'], dtype=object)

# %%
sns.displot(df['petal_length'], bins=10 , kde=False)

# %%
sns.kdeplot(df['petal_length'], shade=True)
# Out:
# <ipython-input-25-f367b4a18def>:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['petal_length'], shade=True)
# <Axes: xlabel='petal_length', ylabel='Density'>

# %%
sns.lineplot(x=df['sepal_length'], y=df['sepal_width'] , data=df)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>
